# %%
# Treinando manipulação de dicionários

produtos = [
    'Notebook',
    'Smartphone',
    'Tablet',
    'Monitor',
    'Teclado',
    'Mouse',
    'Impressora',
    'SSD',
    'HD Externo',
    'Roteador'
]

vendas_2024 = [
    120,
    350,
    95,
    180,
    210,
    260,
    75,
    220,
    130,
    160
]

vendas_2025 = [
    145,
    380,
    110,
    200,
    230,
    290,
    90,
    260,
    155,
    185
]

# %%
# Estrutura - {produto: [venda2024, vendas2025]}

vendas = list(zip(vendas_2024, vendas_2025))

dados_vendas = dict(zip(produtos, vendas))

#for i, produto in enumerate(produtos):

    #dados_vendas[produto] = vendas[i]

print(dados_vendas)
# Out:
# {'Notebook': (120, 145), 'Smartphone': (350, 380), 'Tablet': (95, 110), 'Monitor': (180, 200), 'Teclado': (210, 230), 'Mouse': (260, 290), 'Impressora': (75, 90), 'SSD': (220, 260), 'HD Externo': (130, 155), 'Roteador': (160, 185)}
